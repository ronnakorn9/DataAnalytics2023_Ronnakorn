# %%
import json
import spacy
from spacy.tokens import DocBin, Span, SpanGroup

# %%
path = "C:/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/data/raw/sem_eval_task6/"
save_path = "C:/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/data/converted/sem_eval_task6/"
filename = "dev_set_task2.json"
# filename = "training_set_task2.json"
save_filename = "dev_set_task4.spacy"
# save_filename = "training_set_task4.spacy"
text_only = True

with open(path + filename, 'r', encoding="utf-8") as input_file:
    data = input_file.read()
    structure = json.loads(data)

len(structure)
# Out:
# 63

# %%
label_path = "C:/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/data/raw/sem_eval_task6/valid_label.txt"
with open(label_path, 'r', encoding="utf-8") as input_file:
    categories = input_file.read().strip().split("\n")

# %%
structure
# Out:
# [{'id': '128',
#   'text': 'THERE ARE ONLY TWO GENDERS\n\nFEMALE \n\nMALE\n',
#   'labels': [{'start': 0,
#     'end': 41,
#     'technique': 'Black-and-white Fallacy/Dictatorship',
#     'text_fragment': 'THERE ARE ONLY TWO GENDERS\n\nFEMALE \n\nMALE'}]},
#  {'id': '189', 'text': 'This is not an accident!', 'labels': []},
#  {'id': '96',
#   'text': "SO BERNIE BROS HAVEN'T COMMITTED VIOLENCE EH?\n\nPOWER COMES FROM THE BARREL OF A GUN, COMRADES.\n\nWHAT ABOUT THE ONE WHO SHOT CONGRESSMAN SCALISE OR THE DAYTON OHIO MASS SHOOTER?\n",
#   'labels': [{'end': 83,
#     'start': 47,
#     'technique': 'Slogans',
#     'text_fragment': 'POWER COMES FROM THE BARREL OF A GUN'},
#    {'end': 14,
#     'start': 3,
#     'technique': 'Name calling/Labeling',
#     'text_fragment': 'BERNIE BROS'},
#    {'end': 41,
#     'start': 33,
#     'technique': 'Loaded Language',
#     'text_fragment': 'VIOLENCE'},
#    {'end': 175,
#     'start': 163,
#     'technique': 'Loaded Language',
# ...

# %%
### textcat data
nlp = spacy.blank("en")
doc_bin = DocBin()
for entry in structure:
    if text_only:
        doc = nlp(entry["text"])
        doc.cats = {category: 0 for category in categories}
        for label in entry["labels"]:
            doc.cats[label] = 1

    doc_bin.add(doc)
# doc_bin.to_disk(save_path+save_filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\archa\Desktop\Boss_work\rpi\class\data_analytics\RPI_data_analytics\proj\src\spacy\preprocess.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/src/spacy/preprocess.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>         doc.cats = {category: 0 for category in categories}
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/src/spacy/preprocess.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>         for label in entry["labels"]:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/src/spacy/preprocess.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>             doc.cats[label] = 1
# ...

# %%
text = "NIKE CALLED AND SAID THEY WERE BEING LOOTED-\nBY BLACK LIVES MATTER.\n\nI TOLD THEM TO CALL THE NFL FOR HELP!"

len(text)
print(f"\'{text[42]}\'")
# Out:
# 'D'

# %%
### spancat data
nlp = spacy.blank("en")
doc_bin = DocBin()
span_key = "sc"
for entry in structure:
    if text_only:
        doc = nlp(entry["text"])
        span_list = []
        # print(entry["text"])
        for label in entry["labels"]:
            
            # print(f"\"{label['text_fragment']}\"")
            # tup = Span(doc, label["start"], label["end"], label["technique"])
            tup = doc.char_span(label["start"], label["end"], label["technique"])
            span_list.append(tup)

        doc.spans[span_key] = span_list
        # try:
        #     group = SpanGroup(doc, name=span_key, spans=span_list)
        #     doc.spans[span_key] = group
            
        # except:
        #     print(doc)
        #     print(f"\"{label['text_fragment']}\"")
        #     print(span_list)
        #     break
        # doc.spans[span_key] = span_list

    doc_bin.add(doc)
doc_bin.to_disk(save_path+save_filename)

# %% [markdown]
# ### TESTING SITE

# %%
data_dir = "./data/converted/sem_eval_task6/"
data_name = "training_set_task1.spacy"
data_path = "C:/Users/archa/Desktop/Boss_work/rpi/class/data_analytics/RPI_data_analytics/proj/data/converted/sem_eval_task6/training_set_task1.spacy"
doc_bin = DocBin().from_disk(data_path)

# %%
doc_bin.strings
# Out:
# {'',
#  'unreasonable',
#  'Comply',
#  'BANNED',
#  'maduro',
#  'REPETITIVE',
#  'strong',
#  'Syndrome',
#  'ASSAULTED',
#  'FIGURE',
#  'shot',
#  'nonessential',
#  "COULDN'T",
#  'SHOWN',
#  'TODAY',
#  'pray',
#  'identical',
#  'PROFIT',
#  'reasonably',
#  'let',
#  'AFRICAN',
#  'conquer',
#  'nominated',
#  'mumps',
#  'come',
#  'Hollow',
#  'nadler',
#  'site',
#  'IS',
#  'minorities',
#  'OF',
#  'Barron',
#  'ANTHEM',
#  'Antifa',
#  'Threatening',
#  'isolation',
#  'thinks',
#  'female',
#  'Mumps',
#  'glyphosate',
#  'PRIORITIES',
#  'eliminate',
#  'MINISTER',
#  'SOMETHING',
#  'girl',
#  'IMPORTANT',
#  'Twitter',
#  'boycott',
#  'easier',
#  'SECURITY',
#  'represent',
#  'INSANE',
#  'warmonger',
#  'Neither',
#  'outright',
#  'PUSH',
#  'James',
#  'CLINTONS',
#  'THOUGHT',
#  'needs',
#  'american',
#  'irresponsible',
#  'DAWIT',
#  'SUPER',
#  'toilet',
#  'FEDERAL',
#  'HUMANS',
#  'approve',
#  'baghdad',
#  'her',
#  'STEERING',
#  'cuban',
# ...

# %%
import spacy
from spacy.tokens import DocBin

nlp = spacy.blank("en")
training_data = [
  ("Tokyo Tower is 333m tall.", [(0, 11, "BUILDING")]),
]

# %%
# the DocBin will store the example documents
db = DocBin()
for text, annotations in training_data:
    doc = nlp(text)
    ents = []
    for start, end, label in annotations:
        span = doc.char_span(start, end, label=label)
        ents.append(span)
    doc.ents = ents
    db.add(doc)
db.to_disk("./train.spacy")
